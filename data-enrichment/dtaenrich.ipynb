# %%
print ('hello miles')
# Out:
# hello miles

# %%
import pandas as pd #importing pandas
import numpy as np #importing numpy
import json #importing json (wasn't used)
from skimpy import clean_columns #importing a tool from skimpy to clean data

# %%
hid = pd.read_csv('data/HID2015.csv')
zip = pd.read_csv('data/zipcodes.txt')
# Out:
# /var/folders/sn/w009kb0n6zn_x17gcrqvxt2w0000gn/T/ipykernel_14862/3259888688.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   hid = pd.read_csv('data/HID2015.csv')
# /var/folders/sn/w009kb0n6zn_x17gcrqvxt2w0000gn/T/ipykernel_14862/3259888688.py:2: DtypeWarning: Columns (2,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   zip = pd.read_csv('data/zipcodes.txt')

# %%
hid
# Out:
#         Health Service Area Hospital County  Operating Certificate Number  \
# 0                Western NY        Allegany                      226700.0
# 1                Western NY        Allegany                      226700.0
# 2                Western NY        Allegany                      226700.0
# 3                Western NY        Allegany                      226700.0
# 4                Western NY        Allegany                      226700.0
# ...                     ...             ...                           ...
# 2346926         Long Island         Suffolk                     5157003.0
# 2346927         Long Island         Suffolk                     5157003.0
# 2346928                 NaN             NaN                           NaN
# 2346929         Long Island         Suffolk                     5157003.0
# 2346930         Long Island         Suffolk                     5157003.0
#
#          Facility Id                   Facility Name    Age Group  \
# ...

# %%
zip
# Out:
#          Unnamed: 0        X TYPE       ZIPID        FIPS.x          GISJOIN  \
# 0                 1        1    U  G005010001  3.610316e+11  G36010301586071
# 1                 2        2    U  G005010002  3.610316e+11  G36010301586071
# 2                 3        3    U  G005010003  3.610316e+11  G36010301586071
# 3                 4        4    U  G005010004  3.610316e+11  G36010301586071
# 4                 5        5    U  G005010005  3.610316e+11  G36010301586071
# ...             ...      ...  ...         ...           ...              ...
# 3219348     3219349  3219349  NaN  G149055113  3.601500e+11  G36001500004001
# 3219349     3219350  3219350  NaN  G149055114  3.601500e+11  G36001500004001
# 3219350     3219351  3219351  NaN  G149055115  3.601500e+11  G36001500004001
# 3219351     3219352  3219352  NaN  G149055116  3.601501e+11  G36001500109001
# 3219352     3219353  3219353  NaN  G149055117  3.601500e+11  G36001500004001
#
# ...

# %%
hid.columns
# Out:
# Index(['Health Service Area', 'Hospital County',
#        'Operating Certificate Number', 'Facility Id', 'Facility Name',
#        'Age Group', 'Zip Code - 3 digits', 'Gender', 'Race', 'Ethnicity',
#        'Length of Stay', 'Type of Admission', 'Patient Disposition',
#        'Discharge Year', 'CCS Diagnosis Code', 'CCS Diagnosis Description',
#        'CCS Procedure Code', 'CCS Procedure Description', 'APR DRG Code',
#        'APR DRG Description', 'APR MDC Code', 'APR MDC Description',
#        'APR Severity of Illness Code', 'APR Severity of Illness Description',
#        'APR Risk of Mortality', 'APR Medical Surgical Description',
#        'Payment Typology 1', 'Payment Typology 2', 'Payment Typology 3',
#        'Birth Weight', 'Abortion Edit Indicator',
#        'Emergency Department Indicator', 'Total Charges', 'Total Costs'],
#       dtype='object')

# %%
zip.columns
# Out:
# Index(['Unnamed: 0', 'X', 'TYPE', 'ZIPID', 'FIPS.x', 'GISJOIN', 'FIPS.y',
#        'ADI_NATRANK', 'ADI_STATERNK'],
#       dtype='object')

# %%
czip = clean_columns(zip, case='pascal')
czip.columns.tolist()
# Out:
# 8 column names have been cleaned
# ['Unnamed0',
#  'X',
#  'Type',
#  'Zipid',
#  'FipsX',
#  'Gisjoin',
#  'FipsY',
#  'AdiNatrank',
#  'AdiStaternk']

# %%
zip.dtypes
# Out:
# Unnamed: 0        int64
# X                 int64
# TYPE             object
# ZIPID            object
# FIPS.x          float64
# GISJOIN          object
# FIPS.y          float64
# ADI_NATRANK      object
# ADI_STATERNK     object
# dtype: object

# %%
hid.dtypes
# Out:
# Health Service Area                     object
# Hospital County                         object
# Operating Certificate Number           float64
# Facility Id                            float64
# Facility Name                           object
# Age Group                               object
# Zip Code - 3 digits                     object
# Gender                                  object
# Race                                    object
# Ethnicity                               object
# Length of Stay                          object
# Type of Admission                       object
# Patient Disposition                     object
# Discharge Year                           int64
# CCS Diagnosis Code                       int64
# CCS Diagnosis Description               object
# CCS Procedure Code                       int64
# CCS Procedure Description               object
# APR DRG Code                             int64
# APR DRG Description                     object
# ...

# %%
zip_short = [['ZIPID','ADI_NATRANK', 'ADI_STATERNK']]
hid_short = [['Zip_Code_3_digits','Health_Service_Area', 'Hospital_County', 'Facility_Name']]

# %%
data_enr = pd.merge(zip_short, hid_short, left_on=None, right_on=None, left_index=False, right_index=False)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# /Users/miles/data-enrichment/dtaenrich.ipynb Cell 12' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/miles/data-enrichment/dtaenrich.ipynb#ch0000014?line=0'>1</a> data_enr = pd.merge(zip, hid, left_on=None, right_on=None, left_index=False, right_index=False)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py:107, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      <a href='file:///Users/miles/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=89'>90</a> @Substitution("\nleft : DataFrame or named Series")
#      <a href='file:///Users/miles/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=90'>91</a> @Appender(_merge_doc, indents=0)
# ...
